# %%
#imprtant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
import os

# %%
#directories
orginal_dir='/home/usama/Desktop/obd2_project'
data_dir='/home/usama/Desktop/obd2_project/OBD II Dataset'

# %%
#import csv directory folder
dataset=os.path.join(data_dir,"Modified_OBDII.csv")

# %%
#read csv file
dataframe=pd.read_csv(dataset)

# %%
#set the values
data_set=dataframe.values

# %%
#apply get dummies to convert string data into binary form
dataset=pd.get_dummies(dataframe,prefix_sep='_',drop_first=False)
dataset.head()
# Out:
#     Longitude   Latitude  GPS Speed (Meters/second)  \
# 0  -97.662474  30.483089                   2.795157
# 1  -97.662476  30.483068                   0.000000
# 2  -97.662478  30.483006                   0.000000
# 3  -97.662546  30.482689                   0.000000
# 4  -97.662546  30.482689                   0.000000
#
#     Horizontal Dilution of Precision   Altitude   Bearing      G(x)      G(y)  \
# 0                                 93        250     211.6  0.350434  9.163701
# 1                                 98        255       0.0 -6.745979  4.394452
# 2                                105        247       0.0 -0.923281  7.736757
# 3                                101        225       0.0 -4.792311  2.172633
# 4                                101        225       0.0 -0.061368  7.190879
#
#         G(z)   G(calibrated)  ...  Mass Air Flow Rate(g/s)  \
# 0  -2.947818        0.000910  ...                33.759998
# 1  -4.039574       -0.062790  ...                37.200001
# ...

# %%
k=5
k_means=KMeans(n_clusters=k,init='k-means++',n_init=12)
k_means.fit(dataset)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=12, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
label=k_means.labels_

# %%
dataset['Outcomes']=label

# %%
dataset.to_csv(r'/home/usama/Desktop/obd2_project/OBD II Dataset/complete_labeled_OBDII.csv',index=False)

# %%
dataset
# Out:
#        Longitude   Latitude  GPS Speed (Meters/second)  \
# 0     -97.662474  30.483089                   2.795157
# 1     -97.662476  30.483068                   0.000000
# 2     -97.662478  30.483006                   0.000000
# 3     -97.662546  30.482689                   0.000000
# 4     -97.662546  30.482689                   0.000000
# ...          ...        ...                        ...
# 1351  -97.768033  30.574161                   2.946795
# 1352  -97.768063  30.574162                   2.936818
# 1353  -97.768094  30.574162                   2.926175
# 1354  -97.768094  30.574162                   2.926175
# 1355  -97.768094  30.574162                   2.926175
#
#        Horizontal Dilution of Precision   Altitude   Bearing      G(x)  \
# 0                                    93        250     211.6  0.350434
# 1                                    98        255       0.0 -6.745979
# 2                                   105        247       0.0 -0.923281
# ...
